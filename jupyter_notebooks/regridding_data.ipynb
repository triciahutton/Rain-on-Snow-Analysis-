# %%
# !hostname
# Out:
# n20.clstr

# %%
import xarray as xr
import os
import glob
import geopandas as gpd
import pandas as pd
import matplotlib.colors as mcolors
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import xesmf as xe

# %%
shapefile_path = "/center1/DYNDOWN/phutton5/ROS/boundaries/Alaska_Borough_and_Census_Area_Boundaries.shp"
borough_boundaries = gpd.read_file(shapefile_path)
borough_boundaries = borough_boundaries.set_crs(epsg=3338)
borough_boundaries = borough_boundaries.to_crs(epsg=4326)
FNSB_boundary = borough_boundaries[borough_boundaries['CommunityN'] == 'Fairbanks North Star Borough']
FNSB_geom = FNSB_boundary.geometry.iloc[0] 
FNSB_coords = []
FNSB_coords.extend(list(FNSB_geom.exterior.coords))
FNSB_coords = np.array(FNSB_coords)  
FNSB_coords = pd.DataFrame({
    "lon": FNSB_coords[:, 0],
    "lat": FNSB_coords[:, 1]
})

Fairbanks_lat=(64.84)
Fairbanks_lon=(-147.72)

# %% [markdown]
# Loading in 4km ERA5

# %%
#/center1/DYNDOWN/phutton5/ROS/All_of_AK/All_of_AK_netcdf_files

path='/center1/DYNDOWN/phutton5/ROS/All_of_AK/All_of_AK_netcdf_files/'
compare=f'ROS_Monthly*.nc'
file_list = sorted(glob.glob(os.path.join(path, compare)))
combined_ds=xr.open_mfdataset(file_list, combine='by_coords',engine='netcdf4')

os.chdir("/import/beegfs/CMIP6/wrf_era5")
geo_em_path = "geo_em.d02.nc"
geo = xr.open_dataset(geo_em_path)
oceanmask=geo['LU_INDEX']
oceanmask=oceanmask.squeeze(dim='Time')
#oceanmask_expanded = oceanmask.expand_dims(Time=data.Time)

ERA5_4km = combined_ds.where(oceanmask != 17)

lat_era5_4km=ERA5_4km['XLAT']
lon_era5_4km=ERA5_4km['XLONG']
monthlist=['November','December','January','February','March' ]
monthnumberlist=[11,12,1,2,3]

# %%
path='/center1/DYNDOWN/phutton5/ROS/Raw_ERA5/'

#pattern=f'ROS_December_2021_31km.nc'
pattern='ROS_November_2010_31km.nc'
file_list = sorted(glob.glob(os.path.join(path, pattern)))
#openmfdataset
ERA5_raw = xr.open_dataset(path+pattern,engine='netcdf4')
#data = data.fillna(0)
lat_raw=ERA5_raw['latitude']
lon_raw=ERA5_raw['longitude']

ERA5_31km=ERA5_raw
#raw era5 lat dim 68 and long 190 
#era5 4km lat 450 and  long 420

# %% [markdown]
# REGRIDDING AND SAVING the data
# -

# %%
import xarray as xr
import xesmf as xe

lat_coarse = ERA5_31km["latitude"]
lon_coarse = ERA5_31km["longitude"]
src_grid = xr.Dataset({"lat": lat_coarse, "lon": lon_coarse})

lat_fine = ERA5_4km["XLAT"]
lon_fine = ERA5_4km["XLONG"]

tgt_grid = xr.Dataset({"lat": lat_fine, "lon": lon_fine})

regridder = xe.Regridder(src_grid, tgt_grid, method="nearest_s2d", periodic=False, reuse_weights=False)

vars_to_regrid = [
    v for v in ERA5_31km.data_vars
    if {"latitude", "longitude"}.issubset(ERA5_31km[v].dims)
]

ERA5_31_to_4km = xr.Dataset()
for v in vars_to_regrid:
    ERA5_31_to_4km[v] = regridder(ERA5_31km[v])

#ONLY SAVE IF NEEDED IT WORKED!
#ERA5_31_to_4km.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/ROS_December_2021_nearest_regridded_ERA5_31kmto4km_ROS.nc")
print("Saved regridded 31km → 4km data to NetCDF!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 22
#      20 ERA5_31_to_4km = xr.Dataset()
#      21 for v in vars_to_regrid:
# ---> 22     ERA5_31_to_4km[v] = regridder(ERA5_31km[v])
#      24 #ONLY SAVE IF NEEDED IT WORKED!
#      25 #ERA5_31_to_4km.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/ROS_December_2021_nearest_regridded_ERA5_31kmto4km_ROS.nc")
#      26 print("Saved regridded 31km → 4km data to NetCDF!")
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/frontend.py:610, in BaseRegridder.__call__(self, indata, keep_attrs, skipna, na_thres, output_chunks)
#     602     return self.regrid_array(
#     603         indata,
#     604         self.weights.data,
#    (...)
#     607         output_chunks=output_chunks,
#     608     )
#     609 elif isinstance(indata, xr.DataArray):
# --> 610     return self.regrid_dataarray(
#     611         indata,
#     612         keep_attrs=keep_attrs,
#     613         skipna=skipna,
#     614         na_thres=na_thres,
#     615         output_chunks=output_chunks,
#     616     )
#     617 elif isinstance(indata, xr.Dataset):
#     618     return self.regrid_dataset(
#     619         indata,
#     620         keep_attrs=keep_attrs,
#    (...)
#     623         output_chunks=output_chunks,
#     624     )
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/frontend.py:727, in BaseRegridder.regrid_dataarray(self, dr_in, keep_attrs, skipna, na_thres, output_chunks)
#     725 input_horiz_dims, temp_horiz_dims = self._parse_xrinput(dr_in)
#     726 kwargs = dict(skipna=skipna, na_thres=na_thres, output_chunks=output_chunks)
# --> 727 dr_out = xr.apply_ufunc(
#     728     self.regrid_array,
#     729     dr_in,
#     730     self.weights,
#     731     kwargs=kwargs,
#     732     input_core_dims=[input_horiz_dims, ('out_dim', 'in_dim')],
#     733     output_core_dims=[temp_horiz_dims],
#     734     dask='allowed',
#     735     keep_attrs=keep_attrs,
#     736 )
#     738 return self._format_xroutput(dr_out, temp_horiz_dims)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xarray/core/computation.py:1265, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1263 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1264 elif any(isinstance(a, DataArray) for a in args):
# -> 1265     return apply_dataarray_vfunc(
#    1266         variables_vfunc,
#    1267         *args,
#    1268         signature=signature,
#    1269         join=join,
#    1270         exclude_dims=exclude_dims,
#    1271         keep_attrs=keep_attrs,
#    1272     )
#    1273 # feed Variables directly through apply_variable_ufunc
#    1274 elif any(isinstance(a, Variable) for a in args):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xarray/core/computation.py:307, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     302 result_coords, result_indexes = build_output_coords_and_indexes(
#     303     args, signature, exclude_dims, combine_attrs=keep_attrs
#     304 )
#     306 data_vars = [getattr(a, "variable", a) for a in args]
# --> 307 result_var = func(*data_vars)
#     309 out: tuple[DataArray, ...] | DataArray
#     310 if signature.num_outputs > 1:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xarray/core/computation.py:818, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     813     if vectorize:
#     814         func = _vectorize(
#     815             func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     816         )
# --> 818 result_data = func(*input_data)
#     820 if signature.num_outputs == 1:
#     821     result_data = (result_data,)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/frontend.py:703, in BaseRegridder.regrid_array(self, indata, weights, skipna, na_thres, output_chunks)
#     701     outdata = self._regrid(indata, weights, **kwargs)
#     702 else:  # numpy
# --> 703     outdata = self._regrid(indata, weights, **kwargs)
#     704 return outdata
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/frontend.py:636, in BaseRegridder._regrid(indata, weights, shape_in, shape_out, skipna, na_thres)
#     633     indata = np.where(missing, 0.0, indata)
#     635 # apply weights
# --> 636 outdata = apply_weights(weights, indata, shape_in, shape_out)
#     638 # skipna: Compute the influence of missing data at each interpolation point and filter those not meeting acceptable threshold.
#     639 if skipna:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/smm.py:190, in apply_weights(weights, indata, shape_in, shape_out)
#     187     indata = indata.astype('<f8')  # On the fly conversion
#     189 # Dot product
# --> 190 outdata = np.tensordot(
#     191     indata,
#     192     weights,
#     193     axes=((indata.ndim - 2, indata.ndim - 1), (weights.ndim - 2, weights.ndim - 1)),
#     194 )
#     196 # Ensure same dtype as the input.
#     197 outdata = outdata.astype(indata_dtype)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/sparse/numba_backend/_sparse_array.py:294, in SparseArray.__array_function__(self, func, types, args, kwargs)
#     292     pass
#     293 else:
# --> 294     return sparse_func(*args, **kwargs)
#     296 with contextlib.suppress(AttributeError):
#     297     sparse_func = getattr(type(self), func.__name__)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/sparse/numba_backend/_common.py:214, in tensordot(a, b, axes, return_type)
#     212 at = a.transpose(newaxes_a).reshape(newshape_a)
#     213 bt = b.transpose(newaxes_b).reshape(newshape_b)
# --> 214 res = _dot(at, bt, return_type)
#     215 return res.reshape(olda + oldb)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/sparse/numba_backend/_common.py:492, in _dot(a, b, return_type)
#     489 a = a.view(type=np.ndarray)
#     491 if return_type is None or return_type == np.ndarray:
# --> 492     return _dot_ndarray_coo_type(a.dtype, b.dtype)(a, b.coords, b.data, out_shape)
#     493 b = b.T
#     494 coords, data = _dot_ndarray_coo_type_sparse(a.dtype, b.dtype)(a, b.coords, b.data, out_shape)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typed_passes.py:114, in BaseTypeInference.run_pass(self, state)
#     108 """
#     109 Type inference and legalization
#     110 """
#     111 with fallback_context(state, 'Function "%s" failed type inference'
#     112                       % (state.func_id.func_name,)):
#     113     # Type inference
# --> 114     typemap, return_type, calltypes, errs = type_inference_stage(
#     115         state.typingctx,
#     116         state.targetctx,
#     117         state.func_ir,
#     118         state.args,
#     119         state.return_type,
#     120         state.locals,
#     121         raise_errors=self._raise_errors)
#     122     state.typemap = typemap
#     123     # save errors in case of partial typing
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typed_passes.py:95, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      93     infer.build_constraint()
#      94     # return errors in case of partial typing
# ---> 95     errs = infer.propagate(raise_errors=raise_errors)
#      96     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      98 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typeinfer.py:1075, in TypeInferer.propagate(self, raise_errors)
#    1072 oldtoken = newtoken
#    1073 # Errors can appear when the type set is incomplete; only
#    1074 # raise them when there is no progress anymore.
# -> 1075 errors = self.constraints.propagate(self)
#    1076 newtoken = self.get_state_token()
#    1077 self.debug.propagate_finished()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typeinfer.py:572, in CallConstraint.__call__(self, typeinfer)
#     569     fnty = typevars[self.func].getone()
#     570 with new_error_context("resolving callee type: {fnty}",
#     571                        fnty=fnty):
# --> 572     self.resolve(typeinfer, typevars, fnty)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typeinfer.py:595, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     593     fnty = fnty.instance_type
#     594 try:
# --> 595     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     596 except ForceLiteralArg as e:
#     597     # Adjust for bound methods
#     598     folding_args = ((fnty.this,) + tuple(self.args)
#     599                     if isinstance(fnty, types.BoundFunction)
#     600                     else self.args)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typeinfer.py:1569, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1566     return sig
#    1567 else:
#    1568     # Normal non-recursive call
# -> 1569     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/context.py:279, in BaseContext.resolve_function_type(self, func, args, kws)
#     277 # Prefer user definition first
#     278 try:
# --> 279     res = self._resolve_user_function_type(func, args, kws)
#     280 except errors.TypingError as e:
#     281     # Capture any typing error
#     282     last_exception = e
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/context.py:335, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     331         return self.resolve_function_type(func_type, args, kws)
#     333 if isinstance(func, types.Callable):
#     334     # XXX fold this into the __call__ attribute logic?
# --> 335     return func.get_call_type(self, args, kws)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/types/functions.py:311, in BaseFunction.get_call_type(self, context, args, kws)
#     308         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     309         nolitkws = {k: _unlit_non_poison(v)
#     310                     for k, v in kws.items()}
# --> 311         sig = temp.apply(nolitargs, nolitkws)
#     312 except Exception as e:
#     313     if not isinstance(e, errors.NumbaError):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/types/functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/untyped_passes.py:234, in GenericRewrites.run_pass(self, state)
#     230 msg = ('Internal error in pre-inference rewriting '
#     231        'pass encountered during compilation of '
#     232        'function "%s"' % (state.func_id.func_name,))
#     233 with fallback_context(state, msg):
# --> 234     rewrites.rewrite_registry.apply('before-inference', state)
#     235 return True
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/rewrites/registry.py:67, in RewriteRegistry.apply(self, kind, state)
#      65 while work_list:
#      66     key, block = work_list.pop()
# ---> 67     matches = rewrite.match(state.func_ir, block, state.typemap,
#      68                             state.calltypes)
#      69     if matches:
#      70         if config.DEBUG or config.DUMP_IR:
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/rewrites/ir_print.py:19, in RewritePrintCalls.match(self, func_ir, block, typemap, calltypes)
#      17 expr = inst.value
#      18 try:
# ---> 19     callee = func_ir.infer_constant(expr.func)
#      20 except errors.ConstantInferenceError:
#      21     continue
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/ir.py:1551, in FunctionIR.infer_constant(self, name)
#    1549 if isinstance(name, Var):
#    1550     name = name.name
# -> 1551 return self._consts.infer_constant(name)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/consts.py:32, in ConstantInference.infer_constant(self, name, loc)
#      30 if name not in self._cache:
#      31     try:
# ---> 32         self._cache[name] = (True, self._do_infer(name))
#      33     except ConstantInferenceError as exc:
#      34         # Store the exception args only, to avoid keeping
#      35         # a whole traceback alive.
#      36         self._cache[name] = (False, (exc.__class__, exc.args))
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/consts.py:66, in ConstantInference._do_infer(self, name)
#      63     raise ConstantInferenceError(
#      64         "no single definition for %r" % (name,))
#      65 try:
# ---> 66     const = defn.infer_constant()
#      67 except ConstantInferenceError:
#      68     if isinstance(defn, ir.Expr):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/ir.py:615, in Expr.infer_constant(self)
#     614 def infer_constant(self):
# --> 615     raise ConstantInferenceError('%s' % self, loc=self.loc)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/errors.py:706, in ConstantInferenceError.__init__(self, value, loc)
#     705 def __init__(self, value, loc=None):
# --> 706     super(ConstantInferenceError, self).__init__(value, loc=loc)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/errors.py:544, in NumbaError.__init__(self, msg, loc, highlighting)
#     541         return x
#     543 if loc:
# --> 544     new_msg = "%s\n%s\n" % (msg, loc.strformat())
#     545 else:
#     546     new_msg = "%s" % (msg,)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/ir.py:117, in Loc.strformat(self, nlines_up)
#     115 def strformat(self, nlines_up=2):
# --> 117     lines = self.get_lines()
#     119     use_line = self.line
#     121     if self.maybe_decorator:
#     122         # try and sort out a better `loc`, if it's suspected that this loc
#     123         # points at a jit decorator by virtue of
#    (...)
#     126         # get lines, add a dummy entry at the start as lines count from
#     127         # 1 but list index counts from 0
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/site-packages/numba/core/ir.py:97, in Loc.get_lines(self)
#      93     path = self._get_path()
#      94     # Avoid reading from dynamic string. They are most likely
#      95     # overridden. Problem started with Python 3.13. "<string>" seems
#      96     # to be something from multiprocessing.
# ---> 97     lns = [] if path == "<string>" else linecache.getlines(path)
#      98     self.lines = lns
#      99 return self.lines
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except (OSError, UnicodeDecodeError, SyntaxError):
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/tokenize.py:398, in open(filename)
#     396 buffer = _builtin_open(filename, 'rb')
#     397 try:
# --> 398     encoding, lines = detect_encoding(buffer.readline)
#     399     buffer.seek(0)
#     400     text = TextIOWrapper(buffer, encoding, line_buffering=True)
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/tokenize.py:367, in detect_encoding(readline)
#     364         encoding += '-sig'
#     365     return encoding
# --> 367 first = read_or_stop()
#     368 if first.startswith(BOM_UTF8):
#     369     bom_found = True
#
# File ~/miniconda3/envs/dyndown/lib/python3.11/tokenize.py:325, in detect_encoding.<locals>.read_or_stop()
#     323 def read_or_stop():
#     324     try:
# --> 325         return readline()
#     326     except StopIteration:
#     327         return b''
#
# KeyboardInterrupt:

# %%
ERA5_31_to_4km.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/ROS_November_2010_nearest_regridded_ERA5_31kmto4km_ROS.nc")

# %% [markdown]
# Regridding the elevation map from 31km to 4km

# %%
ERA5_raw = xr.open_dataset('/import/AKCASC/data/cds/reanalysis-era5-invariants/era5_geopotential.nc',engine='netcdf4')


import xarray as xr
import xesmf as xe

lat_coarse = ERA5_raw["latitude"]
lon_coarse = ERA5_raw["longitude"]
src_grid = xr.Dataset({"lat": lat_coarse, "lon": lon_coarse})

lat_fine = ERA5_4km["XLAT"]
lon_fine = ERA5_4km["XLONG"]

tgt_grid = xr.Dataset({"lat": lat_fine, "lon": lon_fine})

regridder = xe.Regridder(src_grid, tgt_grid, method="nearest_s2d", periodic=False, reuse_weights=False)

vars_to_regrid = [
    v for v in ERA5_raw.data_vars
    if {"latitude", "longitude"}.issubset(ERA5_raw[v].dims)
]

ERA5_31_to_4km = xr.Dataset()
for v in vars_to_regrid:
    ERA5_31_to_4km[v] = regridder(ERA5_raw[v])

#ONLY SAVE IF NEEDED IT WORKED!
#ERA5_31_to_4km.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/ROS_December_2021_nearest_regridded_ERA5_31kmto4km_ROS.nc")
print("Saved regridded 31km → 4km data to NetCDF!")
# Out:
# Saved regridded 31km → 4km data to NetCDF!

# %%
ERA5_31_to_4km.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/era531km_regridded_elevation.nc")

# %%
ERA5_4km_regridded.transpose("latitude", "longitude",...)

# %%
#This regrids 4km to 31km 
'''import xarray as xr
import xesmf as xe

src_grid = xr.Dataset({"lat": ERA5_4km["XLAT"], "lon": ERA5_4km["XLONG"],})

lon2d, lat2d = xr.broadcast(lon_raw, lat_raw)

tgt_grid = xr.Dataset({"lat": lat2d,"lon": lon2d,})

regridder = xe.Regridder(src_grid, tgt_grid, method="nearest_s2d", periodic=False, reuse_weights=False) #method="bilinear"

vars_to_regrid = [
    v for v in ERA5_4km.data_vars
    if {"south_north", "west_east"}.issubset(ERA5_4km[v].dims)]

ERA5_4km_regridded = xr.Dataset()
for v in vars_to_regrid:
    ERA5_4km_regridded[v] = regridder(ERA5_4km[v])

ERA5_4km_regridded.transpose("latitude", "longitude",...)


ERA5_4km_regridded.to_netcdf("/center1/DYNDOWN/phutton5/ROS/All_of_AK/All_of_AK_netcdf_files/nearest_regridded_ERA5_4km_ROS.nc")
print("Saved ROS stats to NetCDF!")'''
# Out:
# /home/phutton5/miniconda3/envs/dyndown/lib/python3.11/site-packages/xesmf/backend.py:42: UserWarning: Input array is not F_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not F_CONTIGUOUS. ' 'Will affect performance.')
# Saved ROS stats to NetCDF!

# %%
lat=ERA5_4km['XLAT']
lon=ERA5_4km['XLONG']
season_sums = ERA5_4km['ros_tally'].sum(dim='month')
season_avg=np.mean(season_sums,axis=0)

AK_ALBERS_SUBPLOT_KW = {'projection': ccrs.AlbersEqualArea(central_longitude=-154, central_latitude=50,standard_parallels=(55, 65))}
levels = np.linspace(0, 5,60)

fig, ax = plt.subplots(subplot_kw=AK_ALBERS_SUBPLOT_KW, figsize=(10, 4))
cf = ax.contourf(lon, lat, season_avg, levels=levels,extend='max',cmap='Blues',transform=ccrs.PlateCarree())
cbar = fig.colorbar(cf, ax=ax, label='ROS Hourly Count')
cbar.set_ticks(np.arange(0,6,1))
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])
FNSB_boundary.plot(ax=ax, facecolor='none', edgecolor='black',linewidth=1,zorder=2,transform=ccrs.PlateCarree())
ax.scatter(Fairbanks_lon, Fairbanks_lat, marker='*', color='k', zorder=5, s=75, label='Fairbanks', transform=ccrs.PlateCarree())

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)
ax.text(Fairbanks_lon, Fairbanks_lat + 0.05, 'Fairbanks', transform=ccrs.PlateCarree(),
        ha='center', va='bottom', fontsize=8, zorder=6, fontweight='bold', color='black')

ax.set_title("Average ROS Hourly Count for Winter 1959–2022")
ax.set_extent([-149, -143, 64, 66], crs=ccrs.PlateCarree()) 
ax.set_aspect('equal') 
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.show()

# %%
ERA5_31_to_4km
lat=ERA5_31_to_4km['XLAT']
lon=ERA5_31_to_4km['XLONG']
season_sums = ERA5_31_to_4km['ros_tally'].sum(dim='month')
season_avg=np.mean(season_sums,axis=0)

AK_ALBERS_SUBPLOT_KW = {'projection': ccrs.AlbersEqualArea(central_longitude=-154, central_latitude=50,standard_parallels=(55, 65))}
levels = np.linspace(0, 12,60)

fig, ax = plt.subplots(subplot_kw=AK_ALBERS_SUBPLOT_KW, figsize=(10, 4))
cf = ax.contourf(lon, lat, season_avg, levels=levels,extend='max',cmap='Blues',transform=ccrs.PlateCarree())
cbar = fig.colorbar(cf, ax=ax, label='ROS Hourly Count')
cbar.set_ticks(np.arange(0,13,1))
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])
FNSB_boundary.plot(ax=ax, facecolor='none', edgecolor='black',linewidth=1,zorder=2,transform=ccrs.PlateCarree())
ax.scatter(Fairbanks_lon, Fairbanks_lat, marker='*', color='k', zorder=5, s=75, label='Fairbanks', transform=ccrs.PlateCarree())

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)
ax.text(Fairbanks_lon, Fairbanks_lat + 0.05, 'Fairbanks', transform=ccrs.PlateCarree(),
        ha='center', va='bottom', fontsize=8, zorder=6, fontweight='bold', color='black')

ax.set_title("Average ROS Hourly Count for Winter 1959–2022")
ax.set_extent([-149, -143, 64, 66], crs=ccrs.PlateCarree()) 
ax.set_aspect('equal') 
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.show()

# %%
AK_ALBERS_SUBPLOT_KW = {
    'projection': ccrs.AlbersEqualArea(
        central_longitude=-154,
        central_latitude=50,
        standard_parallels=(55, 65))}

fig, ax = plt.subplots(
    subplot_kw=AK_ALBERS_SUBPLOT_KW,
    figsize=(10, 4)
    )
season_sums = ERA5_31_to_4km['ros_tally'].sum(dim='month')
season_avg=np.mean(season_sums,axis=0)
pm = ax.pcolormesh(
    lon,
    lat,
    season_avg,
    cmap='Blues',
    vmin=0,
    vmax=12,
    shading='auto',   # IMPORTANT
    transform=ccrs.PlateCarree()
)

cbar = fig.colorbar(pm, ax=ax, label='ROS Hourly Count')
cbar.set_ticks(np.arange(0, 13, 1))
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])

FNSB_boundary.plot(
    ax=ax,
    facecolor='none',
    edgecolor='black',
    linewidth=1,
    zorder=2,
    transform=ccrs.PlateCarree()
)

ax.scatter(
    Fairbanks_lon,
    Fairbanks_lat,
    marker='*',
    color='k',
    zorder=5,
    s=75,
    label='Fairbanks',
    transform=ccrs.PlateCarree()
)

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)

ax.text(
    Fairbanks_lon,
    Fairbanks_lat + 0.05,
    'Fairbanks',
    transform=ccrs.PlateCarree(),
    ha='center',
    va='bottom',
    fontsize=8,
    zorder=6,
    fontweight='bold',
    color='black'
)

ax.set_title("Average ROS Hourly Count for Winter 1959–2022")
ax.set_extent([-149, -143, 64, 66], crs=ccrs.PlateCarree())
ax.set_aspect('equal')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.show()

# %%
season_sums_31to4 = ERA5_31_to_4km['ros_tally'].sum(dim='month')
season_avg_31to4=np.mean(season_sums_31to4,axis=0)
season_sum_4=ERA5_4km['ros_tally'].sum(dim='month')
season_avg_4=np.mean(season_sum_4,axis=0)

diff=season_avg_31to4-season_avg_4

AK_ALBERS_SUBPLOT_KW = {
    'projection': ccrs.AlbersEqualArea(
        central_longitude=-154,
        central_latitude=50,
        standard_parallels=(55, 65))}

fig, ax = plt.subplots(
    subplot_kw=AK_ALBERS_SUBPLOT_KW,
    figsize=(10, 4))

pm = ax.pcolormesh(
    lon,
    lat,
    diff,
    cmap='coolwarm',
    vmin=-5,
    vmax=5,
    shading='auto',   # IMPORTANT
    transform=ccrs.PlateCarree())

cbar = fig.colorbar(pm, ax=ax, label='ROS Hourly Count')
cbar.set_ticks(np.arange(-5, 6,1))
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])

FNSB_boundary.plot(
    ax=ax,
    facecolor='none',
    edgecolor='black',
    linewidth=1,
    zorder=2,
    transform=ccrs.PlateCarree())

ax.scatter(
    Fairbanks_lon,
    Fairbanks_lat,
    marker='*',
    color='k',
    zorder=5,
    s=75,
    label='Fairbanks',
    transform=ccrs.PlateCarree()
)

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)

ax.text(
    Fairbanks_lon,
    Fairbanks_lat + 0.05,
    'Fairbanks',
    transform=ccrs.PlateCarree(),
    ha='center',
    va='bottom',
    fontsize=8,
    zorder=6,
    fontweight='bold',
    color='black'
)

ax.set_title("Difference 4km ROS Hourly Count for Winter 1959–2022")
ax.set_extent([-165.3, -141, 55.8, 71.38], crs=ccrs.PlateCarree())
ax.set_aspect('equal')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.show()

# %%
season_sums = ERA5_31km_regridded['ros_tally'].sum(dim='month')
seasonal_averageROS_Hrs = season_sums.mean(dim='season')

# TRANSPOSE IS CRITICAL
#seasonal_averageROS_Hrs = seasonal_averageROS_Hrs.transpose("latitude", "longitude")

lon2d, lat2d = np.meshgrid(ERA5_31km_regridded['west_east'].values, ERA5_31km_regridded['south_north'].values)
fig, ax = plt.subplots(subplot_kw=AK_ALBERS_SUBPLOT_KW,figsize=(10, 4))

mesh = ax.pcolormesh(
    lon2d,
    lat2d,
    seasonal_averageROS_Hrs.values,
    cmap=cmap,
    norm=norm,
    shading="auto",
    transform=ccrs.PlateCarree())

cbar = fig.colorbar(mesh, ax=ax, label='ROS Hourly Count', extend='max')
cbar.set_ticks(np.arange(0, 13, 1))
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])

FNSB_boundary.plot(
    ax=ax, facecolor='none', edgecolor='black',
    linewidth=1, zorder=2, transform=ccrs.PlateCarree()
)
ax.scatter(
    Fairbanks_lon, Fairbanks_lat,
    marker='*', color='k', zorder=5, s=75,
    label='Fairbanks', transform=ccrs.PlateCarree()
)
ax.text(Fairbanks_lon, Fairbanks_lat + 0.05, 'Fairbanks', transform=ccrs.PlateCarree(), ha='center', va='bottom', fontsize=8,zorder=6, fontweight='bold', color='black'
)

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)

ax.set_title("Average ROS Hourly Count REGRIDDED\n for 1950-2022")
ax.set_extent([-149, -143, 64, 66], crs=ccrs.PlateCarree())
ax.set_aspect('equal')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 18
#      10 lon2d, lat2d = np.meshgrid(ERA5_31km_regridded['west_east'].values, ERA5_31km_regridded['south_north'].values)
#      12 fig, ax = plt.subplots(subplot_kw=AK_ALBERS_SUBPLOT_KW,figsize=(10, 4))
#      14 mesh = ax.pcolormesh(
#      15     lon2d,
#      16     lat2d,
#      17     seasonal_averageROS_Hrs.values,
# ---> 18     cmap=cmap,
#      19     norm=norm,
#      20     shading="auto",
#      21     transform=ccrs.PlateCarree()
#      22 )
#      24 cbar = fig.colorbar(mesh, ax=ax, label='ROS Hourly Count', extend='max')
#      25 cbar.set_ticks(np.arange(0, 13, 1))
#
# NameError: name 'cmap' is not defined

# %%
season_sums = ERA5_4km_regridded['ros_tally'].sum(dim='month')
seasonal_averageROS_Hrs = season_sums.mean(dim='season')

seasonal_averageROS_Hrs = seasonal_averageROS_Hrs.transpose("latitude", "longitude")

lon2d, lat2d = np.meshgrid(ERA5_4km_regridded['longitude'].values, ERA5_4km_regridded['latitude'].values)

fig, ax = plt.subplots(subplot_kw=AK_ALBERS_SUBPLOT_KW,figsize=(10, 4))

mesh = ax.pcolormesh(
    lon2d,
    lat2d,
    seasonal_averageROS_Hrs.values,
    cmap=cmap,
    norm=norm,
    shading="auto",
    transform=ccrs.PlateCarree())

cbar = fig.colorbar(mesh, ax=ax, label='ROS Hourly Count', extend='max')
cbar.set_ticks(np.arange(0, 51, 1)[::5])
cbar.ax.set_position([0.77, 0.1, 0.02, 0.8])

ax.add_feature(cfeature.BORDERS, zorder=9)
ax.add_feature(cfeature.COASTLINE, zorder=9)
ax.add_feature(cfeature.RIVERS, zorder=9)

ax.set_title("Average ROS Hourly Count REGRIDDED\n for 1950-2022")
ax.set_extent([-165.3, -141, 55.8, 71.38], crs=ccrs.PlateCarree())
ax.set_aspect('equal')
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.tight_layout()
plt.show()
